# %%
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from utilities import model_creation, metrics_and_plots, data_processing
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping
# Let's see our luck
print("We are running {} version of the TensorFlow,\nand we have {} GPUs Available.".format(
    tf.__version__, len(tf.config.list_physical_devices('GPU'))))
# Out:
# 2023-06-07 13:30:58.139542: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-07 13:31:00.116462: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/rudyrachman16/miniconda3/envs/tf/lib/
# 2023-06-07 13:31:00.119867: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/rudyrachman16/miniconda3/envs/tf/lib/
# 2023-06-07 13:31:00.119882: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# We are running 2.11.0 version of the TensorFlow,
# and we have 1 GPUs Available.

# %%
target_size = (128, 128)
batch_size = 32
epochs = 50
input_shape = (128, 128, 3)

METRICS = [
    tf.keras.metrics.TruePositives(name='tp'),
    tf.keras.metrics.FalsePositives(name='fp'),
    tf.keras.metrics.TrueNegatives(name='tn'),
    tf.keras.metrics.FalseNegatives(name='fn'), 
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc'),
    tf.keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
    tf.keras.metrics.SpecificityAtSensitivity(sensitivity=0.5, name = 'Specificity'),
    tf.keras.metrics.SensitivityAtSpecificity(specificity=0.5, name = 'Sensitivity')
]

# %%
# os.chdir("../../Dataset/2_0_1_splitted")
os.chdir("../../Dataset/1_asli_splitted")

train_dir = "train"
test_dir = "test"
val_dir = "validation"


train_iterator = data_processing.generate_iterator(path=train_dir, augmentation = True, 
                                                   rescale = 0, batch_size = batch_size)
test_iterator = data_processing.generate_iterator(path=test_dir, augmentation=False, 
                                                  shuffle=False, rescale=0, batch_size = batch_size)
validation_iterator = data_processing.generate_iterator(path=val_dir, augmentation=False, 
                                                        shuffle=False, rescale=0, batch_size = batch_size)

# data_processing.display_images(train_iterator)
# Out:
# Found 28083 images belonging to 5 classes.
# Found 3508 images belonging to 5 classes.
# Found 3508 images belonging to 5 classes.

# %%
is_hybrid_model = False
is_hybrid_model_main_only = False

is_test_only = False

# %%
# Let's define the callbacks to save the model and reduce the learning rate
import os

## FOR ENHANCED DATASET
save_dir_for_enhanced = os.path.join('..', '..', "Result", '2_4_reference_updated')
if is_hybrid_model:
    if is_hybrid_model_main_only:
        model_name_for_enhanced = 'hybrid_model_main_only'
    else:
        model_name_for_enhanced = 'hybrid_model'
else:
    architecture = "VGG16"
    model_name_for_enhanced = f'from_tensorflow_{architecture}'
if not os.path.isdir(save_dir_for_enhanced):
    os.makedirs(save_dir_for_enhanced)
filepath_for_enhanced = os.path.join(save_dir_for_enhanced, f"{model_name_for_enhanced}.h5")
csv_for_enhanced = os.path.join(save_dir_for_enhanced, f"{model_name_for_enhanced}.csv")

# prepare callbacks for model saving and for learning rate adjustment.
checkpoint_for_enhanced = ModelCheckpoint(filepath=filepath_for_enhanced,
                                          monitor= 'val_Specificity',
                                          verbose=1,
                                          save_best_only=True,
                                          save_weights_only=True,
                                          mode='max')


CSVLogger_for_enhanced = CSVLogger(filename=csv_for_enhanced, separator=',',
                                  append=False)

lr_reducer = ReduceLROnPlateau(factor=0.5,
                               cooldown=0,
                               patience=5,
                               min_lr=1e-6,
                               monitor='val_Specificity',
                               mode='max')

early_stopping = EarlyStopping(patience=6,
                               monitor='val_Specificity',
                               start_from_epoch=6,
                               verbose=1,
                               mode='max')


callbacks_for_enhanced = [checkpoint_for_enhanced, lr_reducer, CSVLogger_for_enhanced, early_stopping]

# %%
if is_hybrid_model:
    if is_hybrid_model_main_only:
        model = model_creation.main_model_only(input_shape=input_shape, num_classes=5, blocks=4)
    else:
        model = model_creation.final_model(input_shape=input_shape, num_classes=5, blocks=4)
else:
    model = model_creation.model_from_tf(input_shape=input_shape, num_classes=5, is_transfer_learning=False)

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
                           loss = tf.keras.losses.CategoricalCrossentropy(),
                           metrics = METRICS)
# plot_model(model, show_shapes=True)

# %%
if not is_test_only:
    history = model.fit(x=train_iterator, epochs=epochs, 
                        validation_data=validation_iterator, 
                        callbacks=callbacks_for_enhanced,
                        batch_size=batch_size)
# Out:
# Epoch 1/50
# 878/878 [==============================] - ETA: 0s - loss: 4.2191 - tp: 20432.0000 - fp: 7498.0000 - tn: 104834.0000 - fn: 7651.0000 - accuracy: 0.8921 - precision: 0.7315 - recall: 0.7276 - auc: 0.8840 - prc: 0.6527 - Specificity: 0.9536 - Sensitivity: 0.9440
# Epoch 1: val_Specificity improved from -inf to 0.94705, saving model to ../../Result/2_4_reference_updated/from_tensorflow_VGG16.h5
# 878/878 [==============================] - 1148s 1s/step - loss: 4.2191 - tp: 20432.0000 - fp: 7498.0000 - tn: 104834.0000 - fn: 7651.0000 - accuracy: 0.8921 - precision: 0.7315 - recall: 0.7276 - auc: 0.8840 - prc: 0.6527 - Specificity: 0.9536 - Sensitivity: 0.9440 - val_loss: 0.8738 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8905 - val_prc: 0.6691 - val_Specificity: 0.9470 - val_Sensitivity: 0.9453 - lr: 0.0010
# Epoch 2/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8716 - tp: 20637.0000 - fp: 7441.0000 - tn: 104891.0000 - fn: 7446.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7349 - auc: 0.8898 - prc: 0.6677 - Specificity: 0.9543 - Sensitivity: 0.9513
# Epoch 2: val_Specificity improved from 0.94705 to 0.95418, saving model to ../../Result/2_4_reference_updated/from_tensorflow_VGG16.h5
# 878/878 [==============================] - 693s 789ms/step - loss: 0.8716 - tp: 20637.0000 - fp: 7441.0000 - tn: 104891.0000 - fn: 7446.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7349 - auc: 0.8898 - prc: 0.6677 - Specificity: 0.9543 - Sensitivity: 0.9513 - val_loss: 0.8686 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8923 - val_prc: 0.6784 - val_Specificity: 0.9542 - val_Sensitivity: 0.9424 - lr: 0.0010
# Epoch 3/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8705 - tp: 20639.0000 - fp: 7442.0000 - tn: 104890.0000 - fn: 7444.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7349 - auc: 0.8904 - prc: 0.6697 - Specificity: 0.9537 - Sensitivity: 0.9484
# Epoch 3: val_Specificity improved from 0.95418 to 0.95425, saving model to ../../Result/2_4_reference_updated/from_tensorflow_VGG16.h5
# 878/878 [==============================] - 555s 632ms/step - loss: 0.8705 - tp: 20639.0000 - fp: 7442.0000 - tn: 104890.0000 - fn: 7444.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7349 - auc: 0.8904 - prc: 0.6697 - Specificity: 0.9537 - Sensitivity: 0.9484 - val_loss: 0.8680 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8926 - val_prc: 0.6819 - val_Specificity: 0.9542 - val_Sensitivity: 0.9501 - lr: 0.0010
# Epoch 4/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8699 - tp: 20634.0000 - fp: 7440.0000 - tn: 104892.0000 - fn: 7449.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7348 - auc: 0.8898 - prc: 0.6675 - Specificity: 0.9552 - Sensitivity: 0.9489
# Epoch 4: val_Specificity improved from 0.95425 to 0.96031, saving model to ../../Result/2_4_reference_updated/from_tensorflow_VGG16.h5
# 878/878 [==============================] - 256s 292ms/step - loss: 0.8699 - tp: 20634.0000 - fp: 7440.0000 - tn: 104892.0000 - fn: 7449.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7348 - auc: 0.8898 - prc: 0.6675 - Specificity: 0.9552 - Sensitivity: 0.9489 - val_loss: 0.8694 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8944 - val_prc: 0.6899 - val_Specificity: 0.9603 - val_Sensitivity: 0.9507 - lr: 0.0010
# Epoch 5/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8863 - tp: 20581.0000 - fp: 7429.0000 - tn: 104903.0000 - fn: 7502.0000 - accuracy: 0.8937 - precision: 0.7348 - recall: 0.7329 - auc: 0.8899 - prc: 0.6706 - Specificity: 0.9541 - Sensitivity: 0.9495
# Epoch 5: val_Specificity did not improve from 0.96031
# 878/878 [==============================] - 254s 289ms/step - loss: 0.8863 - tp: 20581.0000 - fp: 7429.0000 - tn: 104903.0000 - fn: 7502.0000 - accuracy: 0.8937 - precision: 0.7348 - recall: 0.7329 - auc: 0.8899 - prc: 0.6706 - Specificity: 0.9541 - Sensitivity: 0.9495 - val_loss: 0.8661 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8886 - val_prc: 0.6646 - val_Specificity: 0.9339 - val_Sensitivity: 0.8860 - lr: 0.0010
# Epoch 6/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8697 - tp: 20638.0000 - fp: 7444.0000 - tn: 104888.0000 - fn: 7445.0000 - accuracy: 0.8940 - precision: 0.7349 - recall: 0.7349 - auc: 0.8883 - prc: 0.6597 - Specificity: 0.9510 - Sensitivity: 0.9450
# Epoch 6: val_Specificity did not improve from 0.96031
# 878/878 [==============================] - 255s 291ms/step - loss: 0.8697 - tp: 20638.0000 - fp: 7444.0000 - tn: 104888.0000 - fn: 7445.0000 - accuracy: 0.8940 - precision: 0.7349 - recall: 0.7349 - auc: 0.8883 - prc: 0.6597 - Specificity: 0.9510 - Sensitivity: 0.9450 - val_loss: 0.8688 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8919 - val_prc: 0.6763 - val_Specificity: 0.9547 - val_Sensitivity: 0.9490 - lr: 0.0010
# Epoch 7/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8693 - tp: 20639.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7444.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7349 - auc: 0.8887 - prc: 0.6637 - Specificity: 0.9500 - Sensitivity: 0.9447
# Epoch 7: val_Specificity did not improve from 0.96031
# 878/878 [==============================] - 252s 287ms/step - loss: 0.8693 - tp: 20639.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7444.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7349 - auc: 0.8887 - prc: 0.6637 - Specificity: 0.9500 - Sensitivity: 0.9447 - val_loss: 0.8657 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8910 - val_prc: 0.6785 - val_Specificity: 0.9368 - val_Sensitivity: 0.8860 - lr: 0.0010
# Epoch 8/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8692 - tp: 20640.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7443.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7350 - auc: 0.8895 - prc: 0.6663 - Specificity: 0.9521 - Sensitivity: 0.9457
# Epoch 8: val_Specificity did not improve from 0.96031
# 878/878 [==============================] - 252s 286ms/step - loss: 0.8692 - tp: 20640.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7443.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7350 - auc: 0.8895 - prc: 0.6663 - Specificity: 0.9521 - Sensitivity: 0.9457 - val_loss: 0.8683 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8887 - val_prc: 0.6646 - val_Specificity: 0.9339 - val_Sensitivity: 0.8860 - lr: 0.0010
# Epoch 9/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8700 - tp: 20640.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7443.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7350 - auc: 0.8886 - prc: 0.6611 - Specificity: 0.9529 - Sensitivity: 0.9495
# Epoch 9: val_Specificity did not improve from 0.96031
# 878/878 [==============================] - 248s 283ms/step - loss: 0.8700 - tp: 20640.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7443.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7350 - auc: 0.8886 - prc: 0.6611 - Specificity: 0.9529 - Sensitivity: 0.9495 - val_loss: 0.8679 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8892 - val_prc: 0.6616 - val_Specificity: 0.9339 - val_Sensitivity: 0.8860 - lr: 0.0010
# Epoch 10/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8684 - tp: 20640.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7443.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7350 - auc: 0.8885 - prc: 0.6603 - Specificity: 0.9544 - Sensitivity: 0.9466
# Epoch 10: val_Specificity did not improve from 0.96031
# 878/878 [==============================] - 247s 281ms/step - loss: 0.8684 - tp: 20640.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7443.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7350 - auc: 0.8885 - prc: 0.6603 - Specificity: 0.9544 - Sensitivity: 0.9466 - val_loss: 0.8662 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8886 - val_prc: 0.6615 - val_Specificity: 0.9339 - val_Sensitivity: 0.8860 - lr: 5.0000e-04
# Epoch 11/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8683 - tp: 20640.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7443.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7350 - auc: 0.8888 - prc: 0.6595 - Specificity: 0.9503 - Sensitivity: 0.9492
# Epoch 11: val_Specificity did not improve from 0.96031
# 878/878 [==============================] - 248s 282ms/step - loss: 0.8683 - tp: 20640.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7443.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7350 - auc: 0.8888 - prc: 0.6595 - Specificity: 0.9503 - Sensitivity: 0.9492 - val_loss: 0.8668 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8886 - val_prc: 0.6615 - val_Specificity: 0.9339 - val_Sensitivity: 0.8860 - lr: 5.0000e-04
# Epoch 12/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8678 - tp: 20638.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7445.0000 - accuracy: 0.8940 - precision: 0.7349 - recall: 0.7349 - auc: 0.8897 - prc: 0.6656 - Specificity: 0.9499 - Sensitivity: 0.9459
# Epoch 12: val_Specificity did not improve from 0.96031
# 878/878 [==============================] - 246s 280ms/step - loss: 0.8678 - tp: 20638.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7445.0000 - accuracy: 0.8940 - precision: 0.7349 - recall: 0.7349 - auc: 0.8897 - prc: 0.6656 - Specificity: 0.9499 - Sensitivity: 0.9459 - val_loss: 0.8683 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8916 - val_prc: 0.6786 - val_Specificity: 0.9341 - val_Sensitivity: 0.9379 - lr: 5.0000e-04
# Epoch 13/50
# 878/878 [==============================] - ETA: 0s - loss: 0.8682 - tp: 20640.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7443.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7350 - auc: 0.8890 - prc: 0.6629 - Specificity: 0.9518 - Sensitivity: 0.9501
# Epoch 13: val_Specificity did not improve from 0.96031
# 878/878 [==============================] - 247s 281ms/step - loss: 0.8682 - tp: 20640.0000 - fp: 7443.0000 - tn: 104889.0000 - fn: 7443.0000 - accuracy: 0.8940 - precision: 0.7350 - recall: 0.7350 - auc: 0.8890 - prc: 0.6629 - Specificity: 0.9518 - Sensitivity: 0.9501 - val_loss: 0.8662 - val_tp: 2580.0000 - val_fp: 928.0000 - val_tn: 13104.0000 - val_fn: 928.0000 - val_accuracy: 0.8942 - val_precision: 0.7355 - val_recall: 0.7355 - val_auc: 0.8892 - val_prc: 0.6617 - val_Specificity: 0.9339 - val_Sensitivity: 0.8860 - lr: 5.0000e-04
# Epoch 13: early stopping

# %%
if not is_test_only:
    import numpy as np
    np.save('history.npy', history.history)
    # In order to load, we will use the following line
    # history1 = np.load('history.npy', allow_pickle=True).item()

# %%
if not is_test_only:
    metrics_and_plots.plot_metrics(history)

# %%
model.load_weights(filepath_for_enhanced)

# %%
test_predictions_baseline = model.predict(test_iterator, batch_size=64)
y_test = to_categorical(test_iterator.labels)
# Out:
# 110/110 [==============================] - 60s 540ms/step

# %%
baseline_results = model.evaluate(test_iterator,
                                  batch_size=64, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
    print(name, ': ', value)
print('.......................................')
# Out:
# loss :  0.870614230632782
# tp :  2580.0
# fp :  928.0
# tn :  13104.0
# fn :  928.0
# accuracy :  0.8941847085952759
# precision :  0.7354618310928345
# recall :  0.7354618310928345
# auc :  0.8943500518798828
# prc :  0.6846936941146851
# Specificity :  0.9598061442375183
# Sensitivity :  0.9521094560623169
# .......................................

# %%
# Compute ROC curve and ROC area for each class

y_score = test_predictions_baseline
n_classes = 5
metrics_and_plots.plot_roc(y_test, y_score, 5)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score, ConfusionMatrixDisplay

# %%
def predict_label_by_category(predict_categorical):
    for result in predict_categorical:
        yield tf.math.argmax(result).numpy()

# %%
test_label = list(predict_label_by_category(y_test))
predict_label = list(predict_label_by_category(y_score))

# %%
print(f"F1 score - micro: {f1_score(test_label, predict_label, average='micro')}\nF1 score - macro: {f1_score(test_label, predict_label, average='macro')}\nF1 score - weighted: {f1_score(test_label, predict_label, average='weighted')}")
# Out:
# F1 score - micro: 0.7354618015963512
# F1 score - macro: 0.16951379763469118
# F1 score - weighted: 0.6233546150192464
